# %%
# 🐍 ⚜️ 🍁 imports
import pandas as pd
import numpy as np
import random as rd

# %% [markdown]
# ### 🐍 observações

# %% [markdown]
# talvez seja aqui que se faça válida toda a mistica em volta da duo ***python & pandas***
#
#
# simplesmente é muito intuitivo e amigável a forma como se manuseiam condições para uma um dataset tão grande! estou empolgado

# %% [markdown]
# ### 🐍 como usar uma interrogativa [ñ sei o termo correto]

# %% [markdown]
# eu posso simplesmente sujeitar uma serie a uma interrogativa, onde será atribuido a cada item a reposta de True | False

# %%
foo = pd.Series(data = (i for i in range(10)), index = (i for i in 'abcdefghij'))
## pegando os ímpares
foo % 2 == 1
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f     True
# g    False
# h     True
# i    False
# j     True
# dtype: bool

# %% [markdown]
# mas não acaba aqui, eu posso salvar essa nova serie em uma var

# %%
var = foo % 2 == 1
var
#var.to_numpy() pode ser útil em alguns casos
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f     True
# g    False
# h     True
# i    False
# j     True
# dtype: bool

# %% [markdown]
# repare que var é uma  serie com todos os itens ainda sim, se eu quiser de fato filtrar para ter só os com o valor True eu posso percorrer var usando var como parâmetro
#
# [ñ entendi isso muito bem]

# %%
impares = var[var]

# %% [markdown]
# repare que eu só tenho acesso au index label, portanto só posso usar isso para me referenciar a foo se quiser obter os valores de verdade

# %%
foo.loc[impares.index]
# Out:
# b    1
# d    3
# f    5
# h    7
# j    9
# dtype: int64

# %% [markdown]
# ### 🐍 operadores

# %% [markdown]
# #### ⚜️ &

# %% [markdown]
# "E comercial"

# %% [markdown]
# (pergunta 1) ***&*** (pergunta 2)
#
# se isso ***e*** se aquilo

# %% [markdown]
# #### ⚜️ |

# %% [markdown]
# "pipe"

# %% [markdown]
# (pergunta 1) ***|*** (pergunta 2)
#
# se isso ***ou*** se aquilo

# %% [markdown]
# #### ⚜️ posso aliar condicionais desde que os index das duas ou demais series seja mos mesmos!

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# - enagnei vocês

# %% [markdown]
# ### 🐍 salvar a condição em uma variável???

# %% [markdown]
# se eu atribuir a variável "mask" a um subconjunto de uma serie "foo"
#
# então essa máscara vai servir como uma condicional, se eu relacionar ao mesmo objeto

# %% [markdown]
# #### ⚜️ ~

# %% [markdown]
# a presença desse elemento antes do subonjunto simplesmente inverte as condições que aquele subconjunto atende

# %%
foo = pd.Series(data = (i for i in range(10)), index = (i for i in 'abcdefghij'))
mask = foo % 2 == 1 ## pegando os ímpares
mask
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f     True
# g    False
# h     True
# i    False
# j     True
# dtype: bool

# %%
~mask
# Out:
# a     True
# b    False
# c     True
# d    False
# e     True
# f    False
# g     True
# h    False
# i     True
# j    False
# dtype: bool

# %% [markdown]
# se a condição fosse o individu ser homem, ter mais de 15 anos e pesar mais de 80kg, quando aplicado o tilda antes, iria me retornar True para o total inverso desse conjunto:
#
# mulheres com menos de 15 anos e 80kg
